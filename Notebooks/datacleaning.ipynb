# %% [markdown]
#  Import the all csv file as in one dataframe

# %%
import pandas as pd

# %%
 fed_data = ['Data/raw_data/MORTGAGE30US.csv', 'Data/raw_data/RRVRUSQ156N.csv', 'Data/raw_data/CPIAUCSL.csv']
dfs = [pd.read_csv(f, parse_dates=True, index_col= 0) for f in fed_data]

# %%
dfs[0]
# Out:
#                   MORTGAGE30US
# observation_date
# 1971-04-02                7.33
# 1971-04-09                7.31
# 1971-04-16                7.31
# 1971-04-23                7.31
# 1971-04-30                7.29
# ...                        ...
# 2024-12-12                6.60
# 2024-12-19                6.72
# 2024-12-26                6.85
# 2025-01-02                6.91
# 2025-01-09                6.93
#
# [2807 rows x 1 columns]

# %%
dfs[2]
# Out:
#                   CPIAUCSL
# observation_date
# 1947-01-01          21.480
# 1947-02-01          21.620
# 1947-03-01          22.000
# 1947-04-01          22.000
# 1947-05-01          21.950
# ...                    ...
# 2024-07-01         313.534
# 2024-08-01         314.121
# 2024-09-01         314.686
# 2024-10-01         315.454
# 2024-11-01         316.441
#
# [935 rows x 1 columns]

# %%
dfs[1]
# Out:
#                   RRVRUSQ156N
# observation_date
# 1956-01-01                6.2
# 1956-04-01                5.9
# 1956-07-01                6.3
# 1956-10-01                5.8
# 1957-01-01                5.3
# ...                       ...
# 2023-07-01                6.6
# 2023-10-01                6.6
# 2024-01-01                6.6
# 2024-04-01                6.6
# 2024-07-01                6.9
#
# [275 rows x 1 columns]

# %%
# Merge the all dataframes on the date index in sungle dataframe
fed_data = pd.concat(dfs, axis=1)

# %%
fed_data.tail(50)

# %% [markdown]
# Note: We have a lot of NaN values in the data. This is because we get rental vacancy rates quarterly, and inflation data is received on a monthly basis. To tackle this issue, we use forward filling and assume that the rental vacancy rate and inflation rate remain constant over the months.

# %%
fed_data = fed_data.ffill().dropna()

# %%
fed_data
# Out:
#                   MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# observation_date
# 1971-04-02                7.33          5.3    40.100
# 1971-04-09                7.31          5.3    40.100
# 1971-04-16                7.31          5.3    40.100
# 1971-04-23                7.31          5.3    40.100
# 1971-04-30                7.29          5.3    40.100
# ...                        ...          ...       ...
# 2024-12-12                6.60          6.9   316.441
# 2024-12-19                6.72          6.9   316.441
# 2024-12-26                6.85          6.9   316.441
# 2025-01-02                6.91          6.9   316.441
# 2025-01-09                6.93          6.9   316.441
#
# [3364 rows x 3 columns]

# %%
print(os.getcwd())
# Out:
# /Users/ankitkumar/Documents/Projects/House-price-prediction/Data/raw_data

# %%
zillow_data = ['Metro_median_sale_price_uc_sfrcondo_week.csv', 'Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_month.csv']
dfs = [pd.read_csv(f) for f in zillow_data]

# %%
dfs[0]
# Out:
#      RegionID  SizeRank             RegionName RegionType StateName
# 0      102001         0          United States    country       NaN  \
# 1      394913         1           New York, NY        msa        NY
# 2      753899         2        Los Angeles, CA        msa        CA
# 3      394463         3            Chicago, IL        msa        IL
# 4      394514         4             Dallas, TX        msa        TX
# ..        ...       ...                    ...        ...       ...
# 185    394720       268         Janesville, WI        msa        WI
# 186    395066       284           Santa Fe, NM        msa        NM
# 187    394493       285            Concord, NH        msa        NH
# 188    395163       287      Traverse City, MI        msa        MI
# 189    394685       289  Homosassa Springs, FL        msa        FL
#
#      2008-02-02  2008-02-09  2008-02-16  2008-02-23  2008-03-01  ...
# 0      175000.0    168000.0    170000.0    166000.0    175000.0  ...  \
# ...

# %%
dfs[1]
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName     1996-02-29
# 0      102001         0    United States    country       NaN  101974.243981  \
# 1      394913         1     New York, NY        msa        NY  178886.438765
# 2      753899         2  Los Angeles, CA        msa        CA  183979.711478
# 3      394463         3      Chicago, IL        msa        IL  129302.420536
# 4      394514         4       Dallas, TX        msa        TX  109454.091687
# ..        ...       ...              ...        ...       ...            ...
# 890    753929       935       Zapata, TX        msa        TX            NaN
# 891    394743       936    Ketchikan, AK        msa        AK            NaN
# 892    753874       937        Craig, CO        msa        CO   67045.328314
# 893    395188       938       Vernon, TX        msa        TX            NaN
# 894    394767       939       Lamesa, TX        msa        TX            NaN
#
# ...

# %%
dfs = [pd.DataFrame(df.iloc[0,5:]) for df in dfs] # Drop the first 5 columns

# %%
dfs[0]
# Out:
#                    0
# 2008-02-02  175000.0
# 2008-02-09  168000.0
# 2008-02-16  170000.0
# 2008-02-23  166000.0
# 2008-03-01  175000.0
# ...              ...
# 2024-11-09  354365.0
# 2024-11-16  359086.0
# 2024-11-23  350000.0
# 2024-11-30  345000.0
# 2024-12-07  362500.0
#
# [880 rows x 1 columns]

# %%
dfs[1]
# Out:
#                         0
# 1996-02-29  101974.243981
# 1996-03-31   102232.42095
# 1996-04-30  102779.727988
# 1996-05-31  103524.018573
# 1996-06-30  104327.643423
# ...                   ...
# 2024-08-31  363136.925494
# 2024-09-30  362263.990521
# 2024-10-31  361209.171257
# 2024-11-30  359655.375146
# 2024-12-31  358461.243801
#
# [347 rows x 1 columns]

# %%
for df in dfs:
    df.index = pd.to_datetime(df.index)
    df['months'] = df.index.to_period('M') # Add a column with the month and year

# %%
dfs[0]
# Out:
#                    0   months
# 2008-02-02  175000.0  2008-02
# 2008-02-09  168000.0  2008-02
# 2008-02-16  170000.0  2008-02
# 2008-02-23  166000.0  2008-02
# 2008-03-01  175000.0  2008-03
# ...              ...      ...
# 2024-11-09  354365.0  2024-11
# 2024-11-16  359086.0  2024-11
# 2024-11-23  350000.0  2024-11
# 2024-11-30  345000.0  2024-11
# 2024-12-07  362500.0  2024-12
#
# [880 rows x 2 columns]

# %%
dfs[1]
# Out:
#                         0   months
# 1996-02-29  101974.243981  1996-02
# 1996-03-31   102232.42095  1996-03
# 1996-04-30  102779.727988  1996-04
# 1996-05-31  103524.018573  1996-05
# 1996-06-30  104327.643423  1996-06
# ...                   ...      ...
# 2024-08-31  363136.925494  2024-08
# 2024-09-30  362263.990521  2024-09
# 2024-10-31  361209.171257  2024-10
# 2024-11-30  359655.375146  2024-11
# 2024-12-31  358461.243801  2024-12
#
# [347 rows x 2 columns]

# %%
price_data = pd.merge(dfs[0], dfs[1], on='months') # Merge the two dataframes on the months column

# %%
price_data.index = dfs[0].index  # Set the index to the date

# %%
price_data
# Out:
#                  0_x   months            0_y
# 2008-02-02  175000.0  2008-02  197407.624475
# 2008-02-09  168000.0  2008-02  197407.624475
# 2008-02-16  170000.0  2008-02  197407.624475
# 2008-02-23  166000.0  2008-02  197407.624475
# 2008-03-01  175000.0  2008-03  196099.010077
# ...              ...      ...            ...
# 2024-11-09  354365.0  2024-11  359655.375146
# 2024-11-16  359086.0  2024-11  359655.375146
# 2024-11-23  350000.0  2024-11  359655.375146
# 2024-11-30  345000.0  2024-11  359655.375146
# 2024-12-07  362500.0  2024-12  358461.243801
#
# [880 rows x 3 columns]

# %%
del price_data['months'] # Drop the months column
price_data
# Out:
#                  0_x            0_y
# 2008-02-02  175000.0  197407.624475
# 2008-02-09  168000.0  197407.624475
# 2008-02-16  170000.0  197407.624475
# 2008-02-23  166000.0  197407.624475
# 2008-03-01  175000.0  196099.010077
# ...              ...            ...
# 2024-11-09  354365.0  359655.375146
# 2024-11-16  359086.0  359655.375146
# 2024-11-23  350000.0  359655.375146
# 2024-11-30  345000.0  359655.375146
# 2024-12-07  362500.0  358461.243801
#
# [880 rows x 2 columns]

# %%
price_data.columns = ['price', 'value'] #  Rename the columns to price and value

# %%
price_data
# Out:
#                price          value
# 2008-02-02  175000.0  197407.624475
# 2008-02-09  168000.0  197407.624475
# 2008-02-16  170000.0  197407.624475
# 2008-02-23  166000.0  197407.624475
# 2008-03-01  175000.0  196099.010077
# ...              ...            ...
# 2024-11-09  354365.0  359655.375146
# 2024-11-16  359086.0  359655.375146
# 2024-11-23  350000.0  359655.375146
# 2024-11-30  345000.0  359655.375146
# 2024-12-07  362500.0  358461.243801
#
# [880 rows x 2 columns]

# %%
fed_data
# Out:
#                   MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# observation_date
# 1971-04-02                7.33          5.3    40.100
# 1971-04-09                7.31          5.3    40.100
# 1971-04-16                7.31          5.3    40.100
# 1971-04-23                7.31          5.3    40.100
# 1971-04-30                7.29          5.3    40.100
# ...                        ...          ...       ...
# 2024-12-12                6.60          6.9   316.441
# 2024-12-19                6.72          6.9   316.441
# 2024-12-26                6.85          6.9   316.441
# 2025-01-02                6.91          6.9   316.441
# 2025-01-09                6.93          6.9   316.441
#
# [3364 rows x 3 columns]

# %%
fed_data.dropna()

# %%
fed_data = fed_data.tail(50)

# %%
price_data
# Out:
#                price          value
# 2008-02-02  175000.0  197407.624475
# 2008-02-09  168000.0  197407.624475
# 2008-02-16  170000.0  197407.624475
# 2008-02-23  166000.0  197407.624475
# 2008-03-01  175000.0  196099.010077
# ...              ...            ...
# 2024-11-09  354365.0  359655.375146
# 2024-11-16  359086.0  359655.375146
# 2024-11-23  350000.0  359655.375146
# 2024-11-30  345000.0  359655.375146
# 2024-12-07  362500.0  358461.243801
#
# [880 rows x 2 columns]

# %%
fed_data.tail(20)
# Out:
#                   MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# observation_date
# 2024-09-12                6.20          6.9   314.686
# 2024-09-19                6.09          6.9   314.686
# 2024-09-26                6.08          6.9   314.686
# 2024-10-01                6.08          6.9   315.454
# 2024-10-03                6.12          6.9   315.454
# 2024-10-10                6.32          6.9   315.454
# 2024-10-17                6.44          6.9   315.454
# 2024-10-24                6.54          6.9   315.454
# 2024-10-31                6.72          6.9   315.454
# 2024-11-01                6.72          6.9   316.441
# 2024-11-07                6.79          6.9   316.441
# 2024-11-14                6.78          6.9   316.441
# 2024-11-21                6.84          6.9   316.441
# 2024-11-27                6.81          6.9   316.441
# 2024-12-05                6.69          6.9   316.441
# 2024-12-12                6.60          6.9   316.441
# ...

# %% [markdown]
# Note: we have observe that dates in the price_data and fed_data are not same. Before we merge the dataframes we need to add to days in fed_data to make the dates same.

# %%
from datetime import timedelta

# %%
fed_data.index = fed_data.index + timedelta(days=2) # Add a day to the index to match the fed data

# %%
fed_data.tail(20)
# Out:
#                   MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# observation_date
# 2024-09-14                6.20          6.9   314.686
# 2024-09-21                6.09          6.9   314.686
# 2024-09-28                6.08          6.9   314.686
# 2024-10-03                6.08          6.9   315.454
# 2024-10-05                6.12          6.9   315.454
# 2024-10-12                6.32          6.9   315.454
# 2024-10-19                6.44          6.9   315.454
# 2024-10-26                6.54          6.9   315.454
# 2024-11-02                6.72          6.9   315.454
# 2024-11-03                6.72          6.9   316.441
# 2024-11-09                6.79          6.9   316.441
# 2024-11-16                6.78          6.9   316.441
# 2024-11-23                6.84          6.9   316.441
# 2024-11-29                6.81          6.9   316.441
# 2024-12-07                6.69          6.9   316.441
# 2024-12-14                6.60          6.9   316.441
# ...

# %%
# merge the two dataframes on the date index
price_data = fed_data.merge(price_data, left_index=True, right_index=True)

# %%
price_data.tail(20)
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL     price          value
# 2024-07-20          6.77          6.9   313.534  360000.0  363248.355507
# 2024-07-27          6.78          6.9   313.534  356000.0  363248.355507
# 2024-08-03          6.73          6.9   314.121  362000.0  363136.925494
# 2024-08-10          6.47          6.9   314.121  355000.0  363136.925494
# 2024-08-17          6.49          6.9   314.121  360000.0  363136.925494
# 2024-08-24          6.46          6.9   314.121  356000.0  363136.925494
# 2024-08-31          6.35          6.9   314.121  360000.0  363136.925494
# 2024-09-07          6.35          6.9   314.686  350000.0  362263.990521
# 2024-09-14          6.20          6.9   314.686  350000.0  362263.990521
# 2024-09-21          6.09          6.9   314.686  350000.0  362263.990521
# 2024-09-28          6.08          6.9   314.686  350000.0  362263.990521
# 2024-10-05          6.12          6.9   315.454  354000.0  361209.171257
# ...

# %%
price_data.columns = ['interest', 'vacancy', 'cpi', 'price', 'value']

# %%
price_data.head()
# Out:
#             interest  vacancy      cpi     price          value
# 2024-03-23      6.87      6.6  312.230  340000.0  352874.411567
# 2024-03-30      6.79      6.6  312.230  350000.0  352874.411567
# 2024-04-06      6.82      6.6  313.207  347500.0  356934.197397
# 2024-04-13      6.88      6.6  313.207  350000.0  356934.197397
# 2024-04-20      7.10      6.6  313.207  351892.0  356934.197397

# %%
import os
directory = '/Users/ankitkumar/Documents/Projects/House-price-prediction/Data/processed_data'
if not os.path.exists(directory):
    os.makedirs(directory)
file_path = os.path.join(directory, 'price_data.csv')
price_data.to_csv(file_path)
